# %% [markdown]
# ## About Me Lab: AI Engineering, Data Analytics & Data Science
#
# In this notebook, you'll write a short introduction about yourself using Python!
#
# ### Instructions:
# - Fill in the variables below with your details.
# - Run the cell to print your introduction.
#
# ### What to Include:
# - Your name.
# - Why you're interested in AI Engineering, Data Analytics or Data Science.
# - A fun fact about yourself or a goal for this course.

# %%
# About Me
# Please fill in the following details.

name = "Paul"
reason = "I'm fascinated by its potential to solve complex problems and automate tedious tasks, freeing up human creativity"
fun_fact = "I'm trying to teach myself to play the guitar, and many other instruments"

print(f"Hi! My name is {name}. I’m excited to learn AI because {reason}. A fun fact about me is: {fun_fact}.")
# Out:
# Hi! My name is Paul. I’m excited to learn because I'm fascinated by its potential to solve complex problems and automate tedious tasks, freeing up human creativity. A fun fact about me is: I'm trying to teach myself to play the guitar, and many other instruments.
